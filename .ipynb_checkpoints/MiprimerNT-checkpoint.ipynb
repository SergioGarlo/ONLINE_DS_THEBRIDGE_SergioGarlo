# %%
print("Hola mundo")
# Out:
# Hola mundo

# %% [markdown]
# Hola Mundo

# %% [markdown]
# # Titulo 1
# ## Titulo 2
# ### Titulo 3
# #### Titulo 4
# ##### Titulo 5
# ###### Titulo 6

# %% [markdown]
# *texto en cursiva*
# **Texto en engrita**
# ***texto en negrita y en cursiva***

# %% [markdown]
# >Sergio
# >>García López

# %% [markdown]
# Hola,
# Mi nombre es Sergio

# %% [markdown]
# 1. Lista ordenada
# 2. Lista ordenada
# 3. Lista ordenada

# %% [markdown]
# * Lista sin orden
# * Lista sin orden
# + Lista sin orden
# - Lista sin orden

# %% [markdown]
# ```Python
# variable = "esto es una variable"
# ```

# %% [markdown]
# ***
# ---

# %% [markdown]
# ![esto es un oso](./oso.png)

# %% [markdown]
# ![esto es un oso](./oso.webp)

# %% [markdown]
# ![minion-removebg-preview.png](attachment:5448af6c-bc81-43a5-aaa6-a24cf201bed4.png)
