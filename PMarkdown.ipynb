# %% [markdown]
# # Mis primeros pasos con Markdown...
#
# ...son muy buenos

# %% [markdown]
# ***texto***

# %% [markdown]
# >Sergio
# >>García López

# %% [markdown]
# Buenas
# mi nombre es sergio

# %% [markdown]
# Hola
# mi nombre es sergio

# %% [markdown]
# ```Python
# variable = "Esto es una variable"
# ```

# %% [markdown]
# ***
# ---
